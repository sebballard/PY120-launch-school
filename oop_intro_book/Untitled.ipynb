# %%
class Laptop:
    def __init__(self, memory):
        self.memory = memory

    @property
    def memory(self):
        return self._memory

    @memory.setter
    def memory(self, memory):
        self._memory  = memory

laptop = Laptop('8GB')
print(laptop.memory)
laptop.memory = '16GB'
print(laptop.memory)
# Out:
# 8GB
# 16GB
